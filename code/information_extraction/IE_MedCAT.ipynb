# %% [markdown]
# ### 1. MedCAT Installation

# %%
# Install medcat
! pip install medcat==1.8.0
try:
    from medcat.cat import CAT
except:
    print("WARNING: Runtime will restart automatically and please run other cells thereafter.")
    exit()
# Out:
# Requirement already satisfied: medcat==1.8.0 in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (1.23.5)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (1.5.3)
# Requirement already satisfied: gensim>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (4.3.1)
# Requirement already satisfied: spacy>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (3.6.1)
# Requirement already satisfied: scipy~=1.9.2 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (1.9.3)
# Requirement already satisfied: transformers<4.22.0,>=4.19.2 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (4.21.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (4.66.1)
# Requirement already satisfied: scikit-learn>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (1.2.2)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (0.3.7)
# Requirement already satisfied: datasets>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (2.14.4)
# Requirement already satisfied: jsonpickle>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (3.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (5.9.5)
# Requirement already satisfied: multiprocess~=0.70.12 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (0.70.15)
# Requirement already satisfied: py2neo~=2021.2.3 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (2021.2.3)
# Requirement already satisfied: aiofiles>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (23.2.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (7.7.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (3.3.0)
# Requirement already satisfied: blis>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (0.7.10)
# Requirement already satisfied: click>=8.0.4 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (8.1.7)
# Requirement already satisfied: pydantic<2.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (1.10.12)
# Requirement already satisfied: aiohttp==3.8.3 in /usr/local/lib/python3.10/dist-packages (from medcat==1.8.0) (3.8.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.3->medcat==1.8.0) (1.3.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (9.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (2.31.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.2->medcat==1.8.0) (6.0.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.3.0->medcat==1.8.0) (6.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (3.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.6.5->medcat==1.8.0) (3.0.8)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->medcat==1.8.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->medcat==1.8.0) (2023.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (2023.7.22)
# Requirement already satisfied: interchange~=2021.0.4 in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (2021.0.4)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (1.6)
# Requirement already satisfied: pansi>=2020.7.3 in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (2020.7.3)
# Requirement already satisfied: pygments>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (2.16.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (1.16.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from py2neo~=2021.2.3->medcat==1.8.0) (2.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0,>=1.10.0->medcat==1.8.0) (4.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.3->medcat==1.8.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.3->medcat==1.8.0) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (0.10.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.1.0->medcat==1.8.0) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->medcat==1.8.0) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->medcat==1.8.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->medcat==1.8.0) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->medcat==1.8.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->medcat==1.8.0) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13.0->medcat==1.8.0) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<4.22.0,>=4.19.2->medcat==1.8.0) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<4.22.0,>=4.19.2->medcat==1.8.0) (0.12.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->medcat==1.8.0) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->medcat==1.8.0) (6.3.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (3.0.39)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.2.2->medcat==1.8.0) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy>=3.1.0->medcat==1.8.0) (0.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (6.5.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=3.1.0->medcat==1.8.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->medcat==1.8.0) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (4.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.9.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->medcat==1.8.0) (2.21)
# /usr/local/lib/python3.10/dist-packages/medcat/cat.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %% [markdown]
# ### 1.1 Import the Medcat Library

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import pickle

from medcat.cat import CAT

import xml.etree.ElementTree as ET

import json

from spacy import displacy

import pandas as pd
import xml.etree.ElementTree as ET

# %% [markdown]
# ### Import the Modelpack

# %% [markdown]
# In this tutorial, we used the SNOMED International modelpack (Full SNOMED modelpack trained on MIMIC-III). To download this model, you need to sign in to your NIH profile/UMLS License using the provided link: <link>https://uts.nlm.nih.gov/uts/login?service=https:%2F%2Fmedcat.rosalind.kcl.ac.uk%2Fauth-callback</link>

# %% [markdown]
# or use the other model package without needing a license
#
# Download from: <link>https://medcat.rosalind.kcl.ac.uk/media/medmen_wstatus_2021_oct.zip</link>

# %%
# Download the models and required data

# !wget -N https://medcat.rosalind.kcl.ac.uk/media/medmen_wstatus_2021_oct.zip
# Out:
# --2023-08-27 16:00:28--  https://medcat.rosalind.kcl.ac.uk/media/medmen_wstatus_2021_oct.zip
# Resolving medcat.rosalind.kcl.ac.uk (medcat.rosalind.kcl.ac.uk)... 193.61.202.139
# Connecting to medcat.rosalind.kcl.ac.uk (medcat.rosalind.kcl.ac.uk)|193.61.202.139|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-08-27 16:00:30 ERROR 404: Not Found.

# %%
# or if it's not working
# !gdown https://drive.google.com/uc?id=1UL6-JlBcWjZZrO_zye_2ufb2Nrod2bpu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UL6-JlBcWjZZrO_zye_2ufb2Nrod2bpu
# To: /content/medmen_wstatus_2021_oct.zip
# 100% 562M/562M [00:03<00:00, 141MB/s]

# %%
#from google.colab import drive
#drive.mount('/content/drive')


DIR = '/content/'
model_pack_path = DIR + "medmen_wstatus_2021_oct.zip"

# %% [markdown]
# ### 1.4 Loading the MedCAT modelpack

# %%
# Load model pack and Create CAT - the main class from medcat used for concept annotation
cat = CAT.load_model_pack(model_pack_path)
# Out:
# WARNING:medcat.cdb:The CDB was exported by an unknown version of MedCAT.
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_md' (3.1.0) was trained with spaCy v3.1.0 and may not be 100% compatible with the current version (3.6.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# INFO:medcat.cat:{
#   "Model ID": null,
#   "Last Modified On": null,
#   "History (from least to most recent)": [],
#   "Description": "No description",
#   "Source Ontology": null,
#   "Location": null,
#   "MetaCAT models": {},
#   "Basic CDB Stats": {},
#   "Performance": {
#     "ner": {},
#     "meta": {}
#   },
#   "Important Parameters (Partial view, all available in cat.config)": {
#     "config.ner.min_name_len": {
#       "value": 3,
#       "description": "Minimum detection length (found terms/mentions shorter than this will not be detected)."
#     },
#     "config.ner.upper_case_limit_len": {
#       "value": 3,
#       "description": "All detected terms shorter than this value have to be uppercase, otherwise they will be ignored."
#     },
#     "config.linking.similarity_threshold": {
#       "value": 0.2,
#       "description": "If the confidence of the model is lower than this a detection will be ignore."
#     },
#     "config.linking.filters.cuis": {
#       "value": 0,
#       "description": "Length of the CUIs filter to be included in outputs. If this is not 0 (i.e. not empty) its best to check what is included before using the model"
#     },
#     "config.general.spell_check": {
#       "value": true,
#       "description": "Is spell checking enabled."
#     },
#     "config.general.spell_check_len_limit": {
#       "value": 7,
#       "description": "Words shorter than this will not be spell checked."
#     }
#   },
#   "MedCAT Version": null
# }

# %%
text = 'Patient presents with a chief complaint of chest pain that radiates to the left arm. The pain began suddenly and is described as squeezing and pressure-like. Patient also reports shortness of breath, nausea, and lightheadedness. Physical examination reveals elevated blood pressure and an irregular heartbeat. Electrocardiogram shows ST-segment elevation indicative of an acute myocardial infarction. The patient is immediately admitted to the cardiac care unit for further evaluation and treatment.'

# %%
# Extract annotated entities in JSON format
annotated_entities_json = cat.get_entities(text)

# Prettify the annotations for better readability
prettified_json = json.dumps(annotated_entities_json, indent=4)

# Display the annotated entities in a readable JSON format
print()
print("Annotated Medical Entities (JSON format):")
print(prettified_json)
# Out:
# Annotated Medical Entities (JSON format):
# {
#     "entities": {
#         "0": {
#             "pretty_name": "Patients",
#             "cui": "C0030705",
#             "type_ids": [
#                 "T101"
#             ],
#             "types": [
#                 "Patient or Disabled Group"
#             ],
#             "source_value": "Patient",
#             "detected_name": "patient",
#             "acc": 0.38499695551547325,
#             "context_similarity": 0.38499695551547325,
#             "start": 0,
#             "end": 7,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 0,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9993436932563782,
#                     "name": "Status"
#                 }
#             }
#         },
#         "3": {
#             "pretty_name": "Chief complaint (finding)",
#             "cui": "C0277786",
#             "type_ids": [
#                 "T033"
#             ],
#             "types": [
#                 "Finding"
#             ],
#             "source_value": "chief complaint",
#             "detected_name": "chief~complaint",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 24,
#             "end": 39,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 3,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999654293060303,
#                     "name": "Status"
#                 }
#             }
#         },
#         "6": {
#             "pretty_name": "Chest Pain",
#             "cui": "C0008031",
#             "type_ids": [
#                 "T184"
#             ],
#             "types": [
#                 "Sign or Symptom"
#             ],
#             "source_value": "chest pain",
#             "detected_name": "chest~pain",
#             "acc": 0.38058956514988307,
#             "context_similarity": 0.38058956514988307,
#             "start": 43,
#             "end": 53,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 6,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9998182654380798,
#                     "name": "Status"
#                 }
#             }
#         },
#         "9": {
#             "pretty_name": "Left upper arm structure",
#             "cui": "C0230347",
#             "type_ids": [
#                 "T023"
#             ],
#             "types": [
#                 "Body Part, Organ, or Organ Component"
#             ],
#             "source_value": "left arm",
#             "detected_name": "left~arm",
#             "acc": 0.2815519235018623,
#             "context_similarity": 0.2815519235018623,
#             "start": 75,
#             "end": 83,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 9,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.996698260307312,
#                     "name": "Status"
#                 }
#             }
#         },
#         "11": {
#             "pretty_name": "Pain",
#             "cui": "C0030193",
#             "type_ids": [
#                 "T184"
#             ],
#             "types": [
#                 "Sign or Symptom"
#             ],
#             "source_value": "pain",
#             "detected_name": "pain",
#             "acc": 0.574852730084479,
#             "context_similarity": 0.574852730084479,
#             "start": 89,
#             "end": 93,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 11,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9998973608016968,
#                     "name": "Status"
#                 }
#             }
#         },
#         "13": {
#             "pretty_name": "Pressure- physical agent",
#             "cui": "C0033095",
#             "type_ids": [
#                 "T067"
#             ],
#             "types": [
#                 "Phenomenon or Process"
#             ],
#             "source_value": "pressure",
#             "detected_name": "pressure",
#             "acc": 0.22110657142117562,
#             "context_similarity": 0.22110657142117562,
#             "start": 143,
#             "end": 151,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 13,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999688863754272,
#                     "name": "Status"
#                 }
#             }
#         },
#         "14": {
#             "pretty_name": "Patients",
#             "cui": "C0030705",
#             "type_ids": [
#                 "T101"
#             ],
#             "types": [
#                 "Patient or Disabled Group"
#             ],
#             "source_value": "Patient",
#             "detected_name": "patient",
#             "acc": 0.45104189799890004,
#             "context_similarity": 0.45104189799890004,
#             "start": 158,
#             "end": 165,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 14,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9990434050559998,
#                     "name": "Status"
#                 }
#             }
#         },
#         "15": {
#             "pretty_name": "Statement of witness:Finding:Point in time:^Witness:Narrative:Reported",
#             "cui": "C4265456",
#             "type_ids": [
#                 "T201"
#             ],
#             "types": [
#                 "Clinical Attribute"
#             ],
#             "source_value": "reports",
#             "detected_name": "report",
#             "acc": 0.25550416223437483,
#             "context_similarity": 0.25550416223437483,
#             "start": 171,
#             "end": 178,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 15,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9991492033004761,
#                     "name": "Status"
#                 }
#             }
#         },
#         "16": {
#             "pretty_name": "Dyspnea",
#             "cui": "C0013404",
#             "type_ids": [
#                 "T184"
#             ],
#             "types": [
#                 "Sign or Symptom"
#             ],
#             "source_value": "shortness of breath",
#             "detected_name": "shortness~of~breath",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 179,
#             "end": 198,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 16,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9995864033699036,
#                     "name": "Status"
#                 }
#             }
#         },
#         "18": {
#             "pretty_name": "Nausea",
#             "cui": "C0027497",
#             "type_ids": [
#                 "T184"
#             ],
#             "types": [
#                 "Sign or Symptom"
#             ],
#             "source_value": "nausea",
#             "detected_name": "nausea",
#             "acc": 0.45755211781670424,
#             "context_similarity": 0.45755211781670424,
#             "start": 200,
#             "end": 206,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 18,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999433755874634,
#                     "name": "Status"
#                 }
#             }
#         },
#         "20": {
#             "pretty_name": "Physical Examination",
#             "cui": "C0031809",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "Physical examination",
#             "detected_name": "physical~examination",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 229,
#             "end": 249,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 20,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9994268417358398,
#                     "name": "Status"
#                 }
#             }
#         },
#         "24": {
#             "pretty_name": "Increase in blood pressure",
#             "cui": "C0497247",
#             "type_ids": [
#                 "T033"
#             ],
#             "types": [
#                 "Finding"
#             ],
#             "source_value": "elevated blood pressure",
#             "detected_name": "elevated~blood~pressure",
#             "acc": 0.4589071570978128,
#             "context_similarity": 0.4589071570978128,
#             "start": 258,
#             "end": 281,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 24,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9691116213798523,
#                     "name": "Status"
#                 }
#             }
#         },
#         "28": {
#             "pretty_name": "irregular",
#             "cui": "C0205271",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "irregular",
#             "detected_name": "irregular",
#             "acc": 0.33913011517670216,
#             "context_similarity": 0.33913011517670216,
#             "start": 289,
#             "end": 298,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 28,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9998093247413635,
#                     "name": "Status"
#                 }
#             }
#         },
#         "29": {
#             "pretty_name": "HB - Heart beat",
#             "cui": "C0425583",
#             "type_ids": [
#                 "T042"
#             ],
#             "types": [
#                 "Organ or Tissue Function"
#             ],
#             "source_value": "heartbeat",
#             "detected_name": "heartbeat",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 299,
#             "end": 308,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 29,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9992883801460266,
#                     "name": "Status"
#                 }
#             }
#         },
#         "30": {
#             "pretty_name": "Electrocardiography",
#             "cui": "C1623258",
#             "type_ids": [
#                 "T060"
#             ],
#             "types": [
#                 "Diagnostic Procedure"
#             ],
#             "source_value": "Electrocardiogram",
#             "detected_name": "electrocardiogram",
#             "acc": 0.5059924300137629,
#             "context_similarity": 0.5059924300137629,
#             "start": 310,
#             "end": 327,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 30,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9998900890350342,
#                     "name": "Status"
#                 }
#             }
#         },
#         "31": {
#             "pretty_name": "segments st",
#             "cui": "C0429029",
#             "type_ids": [
#                 "T033"
#             ],
#             "types": [
#                 "Finding"
#             ],
#             "source_value": "ST-segment",
#             "detected_name": "st~segment",
#             "acc": 0.26127519063262383,
#             "context_similarity": 0.26127519063262383,
#             "start": 334,
#             "end": 344,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 31,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9991078972816467,
#                     "name": "Status"
#                 }
#             }
#         },
#         "33": {
#             "pretty_name": "Elevation",
#             "cui": "C0702240",
#             "type_ids": [
#                 "T082"
#             ],
#             "types": [
#                 "Spatial Concept"
#             ],
#             "source_value": "elevation",
#             "detected_name": "elevation",
#             "acc": 0.4395724661974019,
#             "context_similarity": 0.4395724661974019,
#             "start": 345,
#             "end": 354,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 33,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9986258745193481,
#                     "name": "Status"
#                 }
#             }
#         },
#         "34": {
#             "pretty_name": "Finding",
#             "cui": "C0243095",
#             "type_ids": [
#                 "T033"
#             ],
#             "types": [
#                 "Finding"
#             ],
#             "source_value": "indicative",
#             "detected_name": "indicative",
#             "acc": 0.2438892354231703,
#             "context_similarity": 0.2438892354231703,
#             "start": 355,
#             "end": 365,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 34,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9928556084632874,
#                     "name": "Status"
#                 }
#             }
#         },
#         "37": {
#             "pretty_name": "Acute myocardial infarction",
#             "cui": "C0155626",
#             "type_ids": [
#                 "T047"
#             ],
#             "types": [
#                 "Disease or Syndrome"
#             ],
#             "source_value": "acute myocardial infarction",
#             "detected_name": "acute~myocardial~infarction",
#             "acc": 0.4303979698804634,
#             "context_similarity": 0.4303979698804634,
#             "start": 372,
#             "end": 399,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 37,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9969561100006104,
#                     "name": "Status"
#                 }
#             }
#         },
#         "41": {
#             "pretty_name": "Patients",
#             "cui": "C0030705",
#             "type_ids": [
#                 "T101"
#             ],
#             "types": [
#                 "Patient or Disabled Group"
#             ],
#             "source_value": "patient",
#             "detected_name": "patient",
#             "acc": 0.7736458621902573,
#             "context_similarity": 0.7736458621902573,
#             "start": 405,
#             "end": 412,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 41,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999139308929443,
#                     "name": "Status"
#                 }
#             }
#         },
#         "42": {
#             "pretty_name": "Immediate",
#             "cui": "C0205253",
#             "type_ids": [
#                 "T079"
#             ],
#             "types": [
#                 "Temporal Concept"
#             ],
#             "source_value": "immediately",
#             "detected_name": "immediately",
#             "acc": 0.339660029752177,
#             "context_similarity": 0.339660029752177,
#             "start": 416,
#             "end": 427,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 42,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9991744160652161,
#                     "name": "Status"
#                 }
#             }
#         },
#         "44": {
#             "pretty_name": "Hospital admission",
#             "cui": "C0184666",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "admitted to",
#             "detected_name": "admitted~to",
#             "acc": 0.31707911617349166,
#             "context_similarity": 0.31707911617349166,
#             "start": 428,
#             "end": 439,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 44,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9988364577293396,
#                     "name": "Status"
#                 }
#             }
#         },
#         "45": {
#             "pretty_name": "Heart failure",
#             "cui": "C0018801",
#             "type_ids": [
#                 "T047"
#             ],
#             "types": [
#                 "Disease or Syndrome"
#             ],
#             "source_value": "cardiac",
#             "detected_name": "cardiac",
#             "acc": 0.29131887736111717,
#             "context_similarity": 0.29131887736111717,
#             "start": 444,
#             "end": 451,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 45,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9754160046577454,
#                     "name": "Status"
#                 }
#             }
#         },
#         "46": {
#             "pretty_name": "patient care",
#             "cui": "C0017313",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "care",
#             "detected_name": "care",
#             "acc": 0.27608419710599513,
#             "context_similarity": 0.27608419710599513,
#             "start": 452,
#             "end": 456,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 46,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9773813486099243,
#                     "name": "Status"
#                 }
#             }
#         },
#         "49": {
#             "pretty_name": "Evaluation",
#             "cui": "C0220825",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "evaluation",
#             "detected_name": "evaluation",
#             "acc": 0.7653532548406898,
#             "context_similarity": 0.7653532548406898,
#             "start": 474,
#             "end": 484,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 49,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9985294342041016,
#                     "name": "Status"
#                 }
#             }
#         },
#         "50": {
#             "pretty_name": "Therapeutic procedure",
#             "cui": "C0087111",
#             "type_ids": [
#                 "T061"
#             ],
#             "types": [
#                 "Therapeutic or Preventive Procedure"
#             ],
#             "source_value": "treatment",
#             "detected_name": "treatment",
#             "acc": 0.8080038818068556,
#             "context_similarity": 0.8080038818068556,
#             "start": 489,
#             "end": 498,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 50,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.8960580825805664,
#                     "name": "Status"
#                 }
#             }
#         }
#     },
#     "tokens": []
# }

# %%
# Loop through the annotations in 'annotated_text' and print each CUI and its entity name.

for annotation in list(annotated_entities_json['entities'].values()):
    print(annotation['source_value'],'--', annotation['cui'], annotation['pretty_name'], annotation['types'])
    print()
# Out:
# Patient -- C0030705 Patients ['Patient or Disabled Group']
#
# chief complaint -- C0277786 Chief complaint (finding) ['Finding']
#
# chest pain -- C0008031 Chest Pain ['Sign or Symptom']
#
# left arm -- C0230347 Left upper arm structure ['Body Part, Organ, or Organ Component']
#
# pain -- C0030193 Pain ['Sign or Symptom']
#
# pressure -- C0033095 Pressure- physical agent ['Phenomenon or Process']
#
# Patient -- C0030705 Patients ['Patient or Disabled Group']
#
# reports -- C4265456 Statement of witness:Finding:Point in time:^Witness:Narrative:Reported ['Clinical Attribute']
#
# shortness of breath -- C0013404 Dyspnea ['Sign or Symptom']
#
# nausea -- C0027497 Nausea ['Sign or Symptom']
#
# Physical examination -- C0031809 Physical Examination ['Health Care Activity']
#
# elevated blood pressure -- C0497247 Increase in blood pressure ['Finding']
#
# irregular -- C0205271 irregular ['Qualitative Concept']
#
# heartbeat -- C0425583 HB - Heart beat ['Organ or Tissue Function']
#
# Electrocardiogram -- C1623258 Electrocardiography ['Diagnostic Procedure']
#
# ST-segment -- C0429029 segments st ['Finding']
#
# elevation -- C0702240 Elevation ['Spatial Concept']
#
# indicative -- C0243095 Finding ['Finding']
#
# acute myocardial infarction -- C0155626 Acute myocardial infarction ['Disease or Syndrome']
#
# patient -- C0030705 Patients ['Patient or Disabled Group']
#
# immediately -- C0205253 Immediate ['Temporal Concept']
#
# admitted to -- C0184666 Hospital admission ['Health Care Activity']
#
# cardiac -- C0018801 Heart failure ['Disease or Syndrome']
#
# care -- C0017313 patient care ['Health Care Activity']
#
# evaluation -- C0220825 Evaluation ['Health Care Activity']
#
# treatment -- C0087111 Therapeutic procedure ['Therapeutic or Preventive Procedure']

# %% [markdown]
# ### Retrieving all names and semantic types for a Given CUI.
#
# We can retrieve all concept names from KB associated with the CUI by utilizing <code>cdb.cdb.cui2names</code> and  <code>cdb.cui2type_ids</code>function in <code>cat</code>.

# %%
# Retrieve all names associated with the CUI from the concept database.
cui = "C0008031"
all_names = cat.cdb.cui2names[cui]

# Print the list of names associated with the given CUI.
print(all_names)
# Out:
# {'pain', 'chest~pain'}

# %%
# Retrieve the type_ids associated with the CUI from the concept database.
type_ids = cat.cdb.cui2type_ids[cui]

# Print the list of type_ids associated with the given CUI.
print(type_ids)
# Out:
# {'T184'}

# %% [markdown]
# # 2. Using MedCAT to extract information in clinical trials task

# %% [markdown]
# ### Download and load the data

# %%
# Download the data

# !gdown https://drive.google.com/uc?id=1hcr1ApEze9DYrmAzD1NQhpV7C50_rUbu
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1hcr1ApEze9DYrmAzD1NQhpV7C50_rUbu
# To: /content/ct-topics2022.xml
# 100% 32.4k/32.4k [00:00<00:00, 64.9MB/s]

# %%
data_path = DIR + 'ct-topics2022.xml'

# %%
# Read and Parse XML Data
tree = ET.parse(data_path)
root = tree.getroot()

#  Extract Data and Convert to DataFrame
data = []
for topic in root.findall('topic'):
    number = topic.get('number')
    description = topic.text.strip()

    # Append the extracted data as a dictionary to the 'data' list
    data.append({'Number': number, 'Query': description})

# Create a DataFrame from the extracted data
clinical_df = pd.DataFrame(data)
display(clinical_df)
# Out:
#    Number                                              Query
# 0       1  A 19-year-old male came to clinic with some se...
# 1       2  A 32-year-old woman comes to the hospital with...
# 2       3  A 51-year-old man comes to the office complain...
# 3       4  A 66-year-old woman comes to the office due to...
# 4       5  A 23-year-old man comes to the emergency depar...
# 5       6  A 61-year-old man comes to the clinic due to n...
# 6       7  A 3-year-old girl is brought to the clinic by ...
# 7       8  A 7-month-old boy is brought to emergency by h...
# 8       9  A 67-year-old woman comes to the clinic due to...
# 9      10  A 19-year-old girl comes to the clinic due to ...
# 10     11  A 63-year-old man comes to the clinic for rece...
# 11     12  A 47-year-old man comes to the office for rout...
# 12     13  A 24-year-old man comes to the office complain...
# 13     14  A 39-year-old man comes to the emergency depar...
# 14     15  An 8-year-old boy is brought to the clinic by ...
# 15     16  A 39-year-old woman comes to the clinic compla...
# 16     17  A 67-year-old man comes to the clinic with slo...
# 17     18  A 2-year-old boy is brought to the office by h...
# 18     19  A 7-year-old girl is brought to the emergency ...
# 19     20  A 49-year-old man comes to the office because ...
# 20     21  A 47-year-old man comes to the clinic for the ...
# 21     22  A 15-year-old boy with mild intellectual disab...
# 22     23  A 40-year-old woman comes to the clinic compla...
# 23     24  A 4-year-old boy comes to the office for the f...
# 24     25  A 50-year-old woman comes to the clinic with i...
# 25     26  A 33-year-old woman comes to clinic complainin...
# 26     27  A 31-year-old woman comes to the office due to...
# 27     28  A 23-year-old woman comes to the emergency dep...
# 28     29  A 57-year-old man comes to the emergency depar...
# 29     30  A 47-year-old woman comes to the office compla...
# 30     31  A 25-year-old woman comes to the clinic with h...
# 31     32  A 30-year-old man who is a computer scientist ...
# 32     33  A 20-year-old man comes to the clinic for his ...
# 33     34  A 17-year-old male comes to the office due to ...
# 34     35  A 43-year-old woman, gravida 3 para 3, comes t...
# 35     36  A 47-year-old woman comes to the clinic compla...
# 36     37  A 47-year-old man comes to the office due to w...
# 37     38  A 60-year-old man comes to the clinic complain...
# 38     39  A 55-year-old white woman comes for a routine ...
# 39     40  A 23-year-old female has prolonged oral bleedi...
# 40     41  A 61-year-old man comes to the emergency depar...
# 41     42  A 9-year-old girl is brought to the office for...
# 42     43  A 27-year-old woman comes to the dermatology c...
# 43     44  A 48-year-old man comes to the office complain...
# 44     45  A 15-week-old infant brought to the clinic for...
# 45     46  The patient is a 38-year-old man with cough an...
# 46     47  A 41-year-old woman comes to the dermatology c...
# 47     48  A 20-year-old man comes to the emergency due t...
# 48     49  A 50-year-old woman comes to the clinic compla...
# 49     50  A 70-year-old man comes to the office accompan...

# %%
def annotate_with_medcat(ct_text):
    annotated_ct_text = cat.get_entities(ct_text)
    #print(annotated_ct_text)
    med_concepts = set()
    filter_types = ['Disease or Syndrome', 'Finding', 'Body Part', 'Organ, or Organ Component, Diagnostic Procedure', 'Laboratory or Test Result', 'Sign or Symptom']
    text_input = ''

    for annotation in list(annotated_ct_text['entities'].values()):
        # filter with Disease, Body Part, Organ, or Organ Component, Diagnostic Procedure, Laboratory or Test Result  and Sign or Symptom
        if annotation['types'][0].strip() in filter_types:
          med_concepts.add(annotation['pretty_name'])

    # Join entities into a single text input
    text_input = ', '.join(list(med_concepts))

    return text_input

# %% [markdown]
# ### Print CUI and Corresponding Entity Names from Annotated Text.

# %%
# Apply the processing function to the 'description' column
clinical_df['medcat_query'] = clinical_df['Query'].apply(annotate_with_medcat)
display(clinical_df)
# Out:
#    Number                                              Query  \
# 0       1  A 19-year-old male came to clinic with some se...
# 1       2  A 32-year-old woman comes to the hospital with...
# 2       3  A 51-year-old man comes to the office complain...
# 3       4  A 66-year-old woman comes to the office due to...
# 4       5  A 23-year-old man comes to the emergency depar...
# 5       6  A 61-year-old man comes to the clinic due to n...
# 6       7  A 3-year-old girl is brought to the clinic by ...
# 7       8  A 7-month-old boy is brought to emergency by h...
# 8       9  A 67-year-old woman comes to the clinic due to...
# 9      10  A 19-year-old girl comes to the clinic due to ...
# 10     11  A 63-year-old man comes to the clinic for rece...
# 11     12  A 47-year-old man comes to the office for rout...
# 12     13  A 24-year-old man comes to the office complain...
# 13     14  A 39-year-old man comes to the emergency depar...
# 14     15  An 8-year-old boy is brought to the clinic by ...
# 15     16  A 39-year-old woman comes to the clinic compla...
# 16     17  A 67-year-old man comes to the clinic with slo...
# 17     18  A 2-year-old boy is brought to the office by h...
# 18     19  A 7-year-old girl is brought to the emergency ...
# 19     20  A 49-year-old man comes to the office because ...
# 20     21  A 47-year-old man comes to the clinic for the ...
# 21     22  A 15-year-old boy with mild intellectual disab...
# 22     23  A 40-year-old woman comes to the clinic compla...
# 23     24  A 4-year-old boy comes to the office for the f...
# 24     25  A 50-year-old woman comes to the clinic with i...
# 25     26  A 33-year-old woman comes to clinic complainin...
# 26     27  A 31-year-old woman comes to the office due to...
# 27     28  A 23-year-old woman comes to the emergency dep...
# 28     29  A 57-year-old man comes to the emergency depar...
# 29     30  A 47-year-old woman comes to the office compla...
# 30     31  A 25-year-old woman comes to the clinic with h...
# 31     32  A 30-year-old man who is a computer scientist ...
# 32     33  A 20-year-old man comes to the clinic for his ...
# 33     34  A 17-year-old male comes to the office due to ...
# 34     35  A 43-year-old woman, gravida 3 para 3, comes t...
# 35     36  A 47-year-old woman comes to the clinic compla...
# 36     37  A 47-year-old man comes to the office due to w...
# 37     38  A 60-year-old man comes to the clinic complain...
# 38     39  A 55-year-old white woman comes for a routine ...
# 39     40  A 23-year-old female has prolonged oral bleedi...
# 40     41  A 61-year-old man comes to the emergency depar...
# 41     42  A 9-year-old girl is brought to the office for...
# 42     43  A 27-year-old woman comes to the dermatology c...
# 43     44  A 48-year-old man comes to the office complain...
# 44     45  A 15-week-old infant brought to the clinic for...
# 45     46  The patient is a 38-year-old man with cough an...
# 46     47  A 41-year-old woman comes to the dermatology c...
# 47     48  A 20-year-old man comes to the emergency due t...
# 48     49  A 50-year-old woman comes to the clinic compla...
# 49     50  A 70-year-old man comes to the office accompan...
#
#                                          medcat_query
# 0                                             Finding
# 1   Febrile urinary tract infection, Finding, Abno...
# 2   problems sexual, Hypertensive disease, Fatigue...
# 3   Bone lesion, Hypertensive disease, Stiffness, ...
# 4   Harsh, Other medical condition, Normal systoli...
# 5   Hypertensive disease, Pleural effusion disorde...
# 6   Increased head circumference, First Visit to T...
# 7   Symptoms, Actual Discomfort, Sore to touch, Fi...
# 8   Hypertensive disease, Degenerative polyarthrit...
# 9                    Swelling, Mass of body structure
# 10        Weight decreased, Lesion, Actual Discomfort
# 11  Hypertensive disease, drug exposure, Degenerat...
# 12  Finding, Abnormal, Klinefelter Syndrome, No ab...
# 13  Arthritis, Other medical condition, Pain, Feve...
# 14  Sitting position, Finding, Difficult (qualifie...
# 15  Negative, Exanthema, Drink more alcohol, Fever...
# 16   Medical History, Symptoms, Blurred vision, Worse
# 17                                  Exanthema, Lesion
# 18                Pain, Wheezing, Exanthema, Erythema
# 19  Dyslipidaemia, Coughing, Drink more alcohol, M...
# 20  Finding, Weakness, Ataxia, gait, Combined diso...
# 21  Unstable status, Disease, Calcium level result...
# 22  Disease, erythrocyte sedimentation rate result...
# 23                    No complication, Weeks pregnant
# 24  Diabetes Mellitus, PMH - past medical history,...
# 25  Weight decreased, Fatigue, No difference, Stab...
# 26  Lyme Disease, Pain, Erythema, Exanthema, Physi...
# 27           Other medical condition, Past history of
# 28  Pain, Constipation, Low Back Pain, Chief compl...
# 29  Degenerative polyarthritis, Pain, Drink more a...
# 30     Falls, Injury cause, Chief complaint (finding)
# 31  Medical History, Dyspnea, PMH - past medical h...
# 32                                    Marfan Syndrome
# 33  Eczema, Pain, Drink more alcohol, active sexua...
# 34  Pain, Negative, active sexually, Endometriosis...
# 35  Dizziness, Hypothyroidism, Sensorineural Heari...
# 36  Positive, Hypertensive disease, Fatigue, Weigh...
# 37  Problem, Family history, Tremor, Essential Tre...
# 38  Osteoporosis, Family history, Back Pain, Not s...
# 39  Finding, Abnormal, Positive, Laboratory test f...
# 40  Fatigue, Pain, Chief complaint (finding), Hype...
# 41                 Finding, Overweight, Short stature
# 42  Hyperkeratosis, Exanthema, Ulcer, Thickened, P...
# 43  Peptic Esophagitis, Positive Finding, joints t...
# 44                                      Down Syndrome
# 45  Positive, Myalgia, Tired, Fever, Coughing, Low...
# 46  Married (finding), Erythema, Redness, Drink mo...
# 47                Positive, Maternal, Past history of
# 48  Positive, Exanthema, Erythema, Difficult (qual...
# 49  Hypertensive disease, Finding, Diabetes Mellit...

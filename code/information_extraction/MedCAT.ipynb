# %% [markdown]
# # MedCAT Tutorial
#
# In this tutorial will demonstrate how to use MedCAT in order to extract medical information in Clinical Trials and Consumer Health Search Tasks.
#
# Source:https://github.com/CogStack/MedCATtutorials

# %% [markdown]
# ## 1. MedCAT Installation

# %% [markdown]
# Step 1: Clone MedCAT Repo
#
# <code>git clone https://github.com/CogStack/MedCAT.git </code>
#
# Step 2: Create a MedCAT Environment
#
# <code>python3 -m venv medcat</code>
#
# Step 3: Activate the Virtual Environment -  On Linux/Mac
#
# <code>source medcat/bin/activate</code>
#
# Step 4: Install Jupyter and ipykernel
#
# <code>pip install jupyter ipykernel</code>
#
# Step 5: Add the Virtual Environment as a Kernel
#
# <code>python -m ipykernel install --user --name=medcat</code>

# %% [markdown]
# ### 1.1 Install the Requirements

# %%
import os

# Replace 'medcat_directory_path' with the actual path to the directory containing 'requirements.txt'
medcat_directory_path = 'change_with_github_clone_path'

# Change the current working directory to the MedCAT directory
os.chdir(medcat_directory_path)


# Install the packages listed in 'requirements.txt'
# !pip install -r requirements.txt

# %% [markdown]
# ### 1.2 Import the Medcat Library

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import pickle

from medcat.cat import CAT

import xml.etree.ElementTree as ET

import json

from spacy import displacy

import pandas as pd
import xml.etree.ElementTree as ET

# %% [markdown]
# ### 1.3 Import the Modelpack

# %% [markdown]
# In this tutorial, we used the SNOMED International modelpack (Full SNOMED modelpack trained on MIMIC-III). To download this model, you need to sign in to your NIH profile/UMLS License using the provided link: <link>https://uts.nlm.nih.gov/uts/login?service=https:%2F%2Fmedcat.rosalind.kcl.ac.uk%2Fauth-callback</link>

# %% [markdown]
# or use the other model package without needing a license
#
# Download from: <link>https://medcat.rosalind.kcl.ac.uk/media/medmen_wstatus_2021_oct.zip</link>

# %%
# Download the models and required data
# !wget https://medcat.rosalind.kcl.ac.uk/media/medmen_wstatus_2021_oct.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
model_pack_path = "change_to_modelpack_zip_path"

# %% [markdown]
# ### 1.4 Loading the MedCAT modelpack

# %%
# Load model pack and Create CAT - the main class from medcat used for concept annotation
cat = CAT.load_model_pack(model_pack_path)

# %% [markdown]
# # 2. Using MedCAT to extract information in clinical trials and consumer health searches

# %% [markdown]
# ## 2.1 Clinical Trial Task

# %% [markdown]
# ### Load the data

# %%
# Replace 'DATA_DIR' with the path to the directory containing your data files
DATA_DIR = "change_to_data_directory"

# %%
# Clinical Trials data
clinical_trials_data_path = os.path.join(DATA_DIR, 'ct-topics2022.xml')

# %%
# Read and Parse XML Data
tree = ET.parse(clinical_trials_data_path)
root = tree.getroot()

#  Extract Data and Convert to DataFrame
data = []
for topic in root.findall('topic'):
    number = topic.get('number') 
    description = topic.text.strip() 

    # Append the extracted data as a dictionary to the 'data' list
    data.append({'Number': number, 'Description': description})

# Create a DataFrame from the extracted data
clinical_df = pd.DataFrame(data)

# %%
# We'll show the first 5 rows of the DataFrame to get a quick overview of the data.

# Display top 5 rows
top_5_df = clinical_df.head(5)
print(top_5_df)
# Out:
#   Number                                        Description
# 0      1  A 19-year-old male came to clinic with some se...
# 1      2  A 32-year-old woman comes to the hospital with...
# 2      3  A 51-year-old man comes to the office complain...
# 3      4  A 66-year-old woman comes to the office due to...
# 4      5  A 23-year-old man comes to the emergency depar...

# %% [markdown]
# ### Annotate Description with MedCAT

# %%
# We will now proceed to annotate the medical entities present in the description

# Extract the description from the 1st row
text = clinical_df.iloc[0]['Description']

# Display the description from the 1st row
print("Description from the 1st row:")
print()
print(text)


# Annotate the description with MedCAT
annotated_text = cat(text)

# Display the annotated medical entities
print()
print("Annotated Medical Entities:")
displacy.render(annotated_text, style='ent')
# Out:
# Description from the 1st row:
#
# A 19-year-old male came to clinic with some sexual concern.  He recently engaged in a relationship and is worried about the satisfaction of his girlfriend. He has a "baby face" according to his girlfriend's statement and he is not as muscular as his classmates.  On physical examination, there is some pubic hair and poorly developed secondary sexual characteristics. He is unable to detect coffee smell during the examination, but the visual acuity is normal. Ultrasound reveals the testes volume of 1-2 ml. The hormonal evaluation showed serum testosterone level of 65 ng/dL with low levels of GnRH.
#
# Annotated Medical Entities:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A 19-
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     male
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  came to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clinic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  with some
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sexual concern
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# .  He recently
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engaged
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  in a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     relationship
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  and is worried about the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     satisfaction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  of his girlfriend. He has a &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     baby
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     face
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     according
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  to his girlfriend's
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     statement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  and he is not as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     muscular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  as his classmates.  On
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     physical examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# , there is some pubic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     poorly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     developed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     secondary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  sexual
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     characteristics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# . He is unable to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     detect
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     coffee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  smell during the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     examination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# , but the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     visual acuity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  is
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     normal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ultrasound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  reveals the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     testes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="bac

# %% [markdown]
# ### We can extract the annotated entities in a structured JSON format for further analysis or processing

# %%
# Extract annotated entities in JSON format
annotated_entities_json = cat.get_entities(text)

# Prettify the annotations for better readability
prettified_json = json.dumps(annotated_entities_json, indent=4)

# Display the annotated entities in a readable JSON format
print()
print("Annotated Medical Entities (JSON format):")
print(prettified_json)
# Out:
# Annotated Medical Entities (JSON format):
# {
#     "entities": {
#         "2": {
#             "pretty_name": "year",
#             "cui": "C0439234",
#             "type_ids": [
#                 "T079"
#             ],
#             "types": [
#                 "Temporal Concept"
#             ],
#             "source_value": "year-old",
#             "detected_name": "year~old",
#             "acc": 0.6044525851765753,
#             "context_similarity": 0.6044525851765753,
#             "start": 5,
#             "end": 13,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 2,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9990621209144592,
#                     "name": "Status"
#                 }
#             }
#         },
#         "4": {
#             "pretty_name": "Male population group",
#             "cui": "C0025266",
#             "type_ids": [
#                 "T098"
#             ],
#             "types": [
#                 "Population Group"
#             ],
#             "source_value": "male",
#             "detected_name": "male",
#             "acc": 0.8938750852751193,
#             "context_similarity": 0.8938750852751193,
#             "start": 14,
#             "end": 18,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 4,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9997082352638245,
#                     "name": "Status"
#                 }
#             }
#         },
#         "5": {
#             "pretty_name": "Clinic",
#             "cui": "C0442592",
#             "type_ids": [
#                 "T093"
#             ],
#             "types": [
#                 "Health Care Related Organization"
#             ],
#             "source_value": "clinic",
#             "detected_name": "clinic",
#             "acc": 0.37824311774987035,
#             "context_similarity": 0.37824311774987035,
#             "start": 27,
#             "end": 33,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 5,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9895309209823608,
#                     "name": "Status"
#                 }
#             }
#         },
#         "7": {
#             "pretty_name": "concern",
#             "cui": "C2699424",
#             "type_ids": [
#                 "T078"
#             ],
#             "types": [
#                 "Idea or Concept"
#             ],
#             "source_value": "sexual concern",
#             "detected_name": "sexual~concern",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 44,
#             "end": 58,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 7,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9544774293899536,
#                     "name": "Status"
#                 }
#             }
#         },
#         "10": {
#             "pretty_name": "Involvement with",
#             "cui": "C1314939",
#             "type_ids": [
#                 "T169"
#             ],
#             "types": [
#                 "Functional Concept"
#             ],
#             "source_value": "engaged",
#             "detected_name": "engaged",
#             "acc": 0.3633179661773509,
#             "context_similarity": 0.3633179661773509,
#             "start": 73,
#             "end": 80,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 10,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9997647404670715,
#                     "name": "Status"
#                 }
#             }
#         },
#         "11": {
#             "pretty_name": "Relationships",
#             "cui": "C0439849",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "relationship",
#             "detected_name": "relationship",
#             "acc": 0.8143450596887678,
#             "context_similarity": 0.8143450596887678,
#             "start": 86,
#             "end": 98,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 11,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9992119073867798,
#                     "name": "Status"
#                 }
#             }
#         },
#         "12": {
#             "pretty_name": "Satisfaction",
#             "cui": "C0242428",
#             "type_ids": [
#                 "T041"
#             ],
#             "types": [
#                 "Mental Process"
#             ],
#             "source_value": "satisfaction",
#             "detected_name": "satisfaction",
#             "acc": 0.4089918165614256,
#             "context_similarity": 0.4089918165614256,
#             "start": 124,
#             "end": 136,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 12,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9996305704116821,
#                     "name": "Status"
#                 }
#             }
#         },
#         "13": {
#             "pretty_name": "Infant",
#             "cui": "C0021270",
#             "type_ids": [
#                 "T100"
#             ],
#             "types": [
#                 "Age Group"
#             ],
#             "source_value": "baby",
#             "detected_name": "baby",
#             "acc": 0.4036885373602879,
#             "context_similarity": 0.4036885373602879,
#             "start": 166,
#             "end": 170,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 13,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999203681945801,
#                     "name": "Status"
#                 }
#             }
#         },
#         "14": {
#             "pretty_name": "Face",
#             "cui": "C0015450",
#             "type_ids": [
#                 "T029"
#             ],
#             "types": [
#                 "Body Location or Region"
#             ],
#             "source_value": "face",
#             "detected_name": "face",
#             "acc": 0.37339555370887023,
#             "context_similarity": 0.37339555370887023,
#             "start": 171,
#             "end": 175,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 14,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.999977707862854,
#                     "name": "Status"
#                 }
#             }
#         },
#         "15": {
#             "pretty_name": "Agreement",
#             "cui": "C0680240",
#             "type_ids": [
#                 "T054"
#             ],
#             "types": [
#                 "Social Behavior"
#             ],
#             "source_value": "according",
#             "detected_name": "according",
#             "acc": 0.20920661341533314,
#             "context_similarity": 0.20920661341533314,
#             "start": 177,
#             "end": 186,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 15,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999864101409912,
#                     "name": "Status"
#                 }
#             }
#         },
#         "16": {
#             "pretty_name": "Statement",
#             "cui": "C1710187",
#             "type_ids": [
#                 "T078"
#             ],
#             "types": [
#                 "Idea or Concept"
#             ],
#             "source_value": "statement",
#             "detected_name": "statement",
#             "acc": 0.26111137638567833,
#             "context_similarity": 0.26111137638567833,
#             "start": 207,
#             "end": 216,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 16,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9959864020347595,
#                     "name": "Status"
#                 }
#             }
#         },
#         "17": {
#             "pretty_name": "Muscle",
#             "cui": "C0026845",
#             "type_ids": [
#                 "T024"
#             ],
#             "types": [
#                 "Tissue"
#             ],
#             "source_value": "muscular",
#             "detected_name": "muscular",
#             "acc": 0.2189010924194958,
#             "context_similarity": 0.2189010924194958,
#             "start": 234,
#             "end": 242,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 17,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9572800993919373,
#                     "name": "Status"
#                 }
#             }
#         },
#         "19": {
#             "pretty_name": "Physical Examination",
#             "cui": "C0031809",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "physical examination",
#             "detected_name": "physical~examination",
#             "acc": 1.0,
#             "context_similarity": 1.0,
#             "start": 266,
#             "end": 286,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 19,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9981257319450378,
#                     "name": "Status"
#                 }
#             }
#         },
#         "21": {
#             "pretty_name": "Hair",
#             "cui": "C0018494",
#             "type_ids": [
#                 "T023"
#             ],
#             "types": [
#                 "Body Part, Organ, or Organ Component"
#             ],
#             "source_value": "hair",
#             "detected_name": "hair",
#             "acc": 0.20207458610652057,
#             "context_similarity": 0.20207458610652057,
#             "start": 308,
#             "end": 312,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 21,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9998540878295898,
#                     "name": "Status"
#                 }
#             }
#         },
#         "22": {
#             "pretty_name": "Bad",
#             "cui": "C0205169",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "poorly",
#             "detected_name": "poorly",
#             "acc": 0.2554969803276946,
#             "context_similarity": 0.2554969803276946,
#             "start": 317,
#             "end": 323,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 22,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9997231364250183,
#                     "name": "Status"
#                 }
#             }
#         },
#         "23": {
#             "pretty_name": "Functional",
#             "cui": "C0205245",
#             "type_ids": [
#                 "T169"
#             ],
#             "types": [
#                 "Functional Concept"
#             ],
#             "source_value": "developed",
#             "detected_name": "developed",
#             "acc": 0.2832532500741203,
#             "context_similarity": 0.2832532500741203,
#             "start": 324,
#             "end": 333,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 23,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9972219467163086,
#                     "name": "Status"
#                 }
#             }
#         },
#         "24": {
#             "pretty_name": "Secondary to",
#             "cui": "C0175668",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "secondary",
#             "detected_name": "secondary",
#             "acc": 0.3235882392462601,
#             "context_similarity": 0.3235882392462601,
#             "start": 334,
#             "end": 343,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 24,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9803125262260437,
#                     "name": "Status"
#                 }
#             }
#         },
#         "26": {
#             "pretty_name": "Characteristics",
#             "cui": "C1521970",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "characteristics",
#             "detected_name": "characteristic",
#             "acc": 0.2105295610722413,
#             "context_similarity": 0.2105295610722413,
#             "start": 351,
#             "end": 366,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 26,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9859070777893066,
#                     "name": "Status"
#                 }
#             }
#         },
#         "28": {
#             "pretty_name": "Detection",
#             "cui": "C1511790",
#             "type_ids": [
#                 "T061"
#             ],
#             "types": [
#                 "Therapeutic or Preventive Procedure"
#             ],
#             "source_value": "detect",
#             "detected_name": "detect",
#             "acc": 0.25217731641353275,
#             "context_similarity": 0.25217731641353275,
#             "start": 384,
#             "end": 390,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 28,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9649434089660645,
#                     "name": "Status"
#                 }
#             }
#         },
#         "29": {
#             "pretty_name": "Coffee",
#             "cui": "C0009237",
#             "type_ids": [
#                 "T168"
#             ],
#             "types": [
#                 "Food"
#             ],
#             "source_value": "coffee",
#             "detected_name": "coffee",
#             "acc": 0.38470914117363925,
#             "context_similarity": 0.38470914117363925,
#             "start": 391,
#             "end": 397,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 29,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9896948337554932,
#                     "name": "Status"
#                 }
#             }
#         },
#         "30": {
#             "pretty_name": "Medical Examination",
#             "cui": "C0582103",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "examination",
#             "detected_name": "examination",
#             "acc": 0.4965544906077749,
#             "context_similarity": 0.4965544906077749,
#             "start": 415,
#             "end": 426,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 30,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9553871750831604,
#                     "name": "Status"
#                 }
#             }
#         },
#         "32": {
#             "pretty_name": "Visual Acuity",
#             "cui": "C0042812",
#             "type_ids": [
#                 "T201"
#             ],
#             "types": [
#                 "Clinical Attribute"
#             ],
#             "source_value": "visual acuity",
#             "detected_name": "visual~acuity",
#             "acc": 0.41904942035855175,
#             "context_similarity": 0.41904942035855175,
#             "start": 436,
#             "end": 449,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 32,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9950013756752014,
#                     "name": "Status"
#                 }
#             }
#         },
#         "34": {
#             "pretty_name": "Normal",
#             "cui": "C0205307",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "normal",
#             "detected_name": "normal",
#             "acc": 0.5042954423611666,
#             "context_similarity": 0.5042954423611666,
#             "start": 453,
#             "end": 459,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 34,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9926929473876953,
#                     "name": "Status"
#                 }
#             }
#         },
#         "35": {
#             "pretty_name": "Ultrasonography",
#             "cui": "C0041618",
#             "type_ids": [
#                 "T060"
#             ],
#             "types": [
#                 "Diagnostic Procedure"
#             ],
#             "source_value": "Ultrasound",
#             "detected_name": "ultrasound",
#             "acc": 0.43769671413160394,
#             "context_similarity": 0.43769671413160394,
#             "start": 461,
#             "end": 471,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 35,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.5439066886901855,
#                     "name": "Status"
#                 }
#             }
#         },
#         "37": {
#             "pretty_name": "Testis",
#             "cui": "C0039597",
#             "type_ids": [
#                 "T023"
#             ],
#             "types": [
#                 "Body Part, Organ, or Organ Component"
#             ],
#             "source_value": "testes",
#             "detected_name": "testis",
#             "acc": 0.2588963750795378,
#             "context_similarity": 0.2588963750795378,
#             "start": 484,
#             "end": 490,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 37,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999749660491943,
#                     "name": "Status"
#                 }
#             }
#         },
#         "38": {
#             "pretty_name": "Volume",
#             "cui": "C0449468",
#             "type_ids": [
#                 "T081"
#             ],
#             "types": [
#                 "Quantitative Concept"
#             ],
#             "source_value": "volume",
#             "detected_name": "volume",
#             "acc": 0.753272455005095,
#             "context_similarity": 0.753272455005095,
#             "start": 491,
#             "end": 497,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 38,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9999666213989258,
#                     "name": "Status"
#                 }
#             }
#         },
#         "39": {
#             "pretty_name": "Hormones",
#             "cui": "C0019932",
#             "type_ids": [
#                 "T125"
#             ],
#             "types": [
#                 "Hormone"
#             ],
#             "source_value": "hormonal",
#             "detected_name": "hormonal",
#             "acc": 0.3679830940554014,
#             "context_similarity": 0.3679830940554014,
#             "start": 513,
#             "end": 521,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 39,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.985105037689209,
#                     "name": "Status"
#                 }
#             }
#         },
#         "40": {
#             "pretty_name": "Evaluation",
#             "cui": "C0220825",
#             "type_ids": [
#                 "T058"
#             ],
#             "types": [
#                 "Health Care Activity"
#             ],
#             "source_value": "evaluation",
#             "detected_name": "evaluation",
#             "acc": 0.6161905832895547,
#             "context_similarity": 0.6161905832895547,
#             "start": 522,
#             "end": 532,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 40,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.6173095107078552,
#                     "name": "Status"
#                 }
#             }
#         },
#         "41": {
#             "pretty_name": "Finding",
#             "cui": "C0243095",
#             "type_ids": [
#                 "T033"
#             ],
#             "types": [
#                 "Finding"
#             ],
#             "source_value": "showed",
#             "detected_name": "showed",
#             "acc": 0.221460265917009,
#             "context_similarity": 0.221460265917009,
#             "start": 533,
#             "end": 539,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 41,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.8137571811676025,
#                     "name": "Status"
#                 }
#             }
#         },
#         "43": {
#             "pretty_name": "Serum testosterone measurement",
#             "cui": "C0428413",
#             "type_ids": [
#                 "T059"
#             ],
#             "types": [
#                 "Laboratory Procedure"
#             ],
#             "source_value": "serum testosterone",
#             "detected_name": "serum~testosterone",
#             "acc": 0.3959115512921392,
#             "context_similarity": 0.3959115512921392,
#             "start": 540,
#             "end": 558,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 43,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9289208054542542,
#                     "name": "Status"
#                 }
#             }
#         },
#         "47": {
#             "pretty_name": "Levels (qualifier value)",
#             "cui": "C0441889",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "level of",
#             "detected_name": "level~of",
#             "acc": 0.2894131380598312,
#             "context_similarity": 0.2894131380598312,
#             "start": 559,
#             "end": 567,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 47,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.5797470211982727,
#                     "name": "Status"
#                 }
#             }
#         },
#         "49": {
#             "pretty_name": "Levels (qualifier value)",
#             "cui": "C0441889",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "low levels",
#             "detected_name": "low~level",
#             "acc": 0.5646763133133038,
#             "context_similarity": 0.5646763133133038,
#             "start": 582,
#             "end": 592,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 49,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Affirmed",
#                     "confidence": 0.9983900785446167,
#                     "name": "Status"
#                 }
#             }
#         }
#     },
#     "tokens": []
# }

# %% [markdown]
# ### Filter Medical Entities with Concept Type 'Clinical Attribute'

# %%
# In this step, we will filter the annotated medical entities and extract only those
# that have the concept type 'Clinical Attribute', representing diagnostic findings.

# Initialize a dictionary to store the filtered entities
filtered_entities_dict = dict()

# Iterate through each medical entity annotation
medical_entities_dict = annotated_entities_json["entities"]
for key, entity in medical_entities_dict.items():
    # Check if the entity's concept type is 'finding'
    if entity['types'][0] == 'Clinical Attribute':
        # Add the entity to the filtered dictionary
        filtered_entities_dict[key] = entity

# Prettify the filtered annotations for better readability
prettified_filtered_entities_json = json.dumps(filtered_entities_dict, indent=4)
print(prettified_filtered_entities_json)
# Out:
# {}

# %% [markdown]
# ## 2.2 Consumer Health Search Task

# %%
# File paths for patient and Reddit topics data
chs_topics_path = os.path.join(DATA_DIR, 'topics.txt')

# %%
# Step 1: Read and Parse XML Data
tree = ET.parse(chs_topics_path)
root = tree.getroot()

# Extract Data and Convert to DataFrame
chs_patients_data = []

# Iterate over each 'topic' element in the XML data
for topic in root.findall('topic'):
    topic_id = topic.find('id').text.strip()
    query = topic.find('query').text.strip()
    
    # Append the extracted data as a dictionary to the chs_patients_data list
    chs_patients_data.append({'Number': topic_id, 'Description': query})
    
# Create a DataFrame from the extracted data in chs_patients_data list
chs_df = pd.DataFrame(chs_patients_data)

print(chs_df)
# Display top 5 rows
top_5_chs_df = chs_df.head(5)
print(top_5_df)
# Out:
#    Number                                        Description
# 0       1  What are the most common chronic diseases? Wha...
# 1       8         best apps daily activity exercise diabetes
# 2      22             my risk for developing type 2 diabetes
# 3      35  Is a ketogenic / keto diet suitable for people...
# 4      45                             Can diabetes be cured?
# 5      51  What is holistic medicine and what does it inc...
# 6      52  What are the most common mental health problem...
# 7      53                             what is psychotherapy?
# 8      54  What does multiple sclerosis diagnosis include...
# 9      55                  How to manage multiple sclerosis?
# 10     57                   multiple sclerosis stages phases
# 11     58                 Risk to develop multiple sclerosis
# 12     59    long-term effects likelihood multiple sclerosis
# 13     62  disclosing multiple sclerosis at work, how wil...
# 14     63          Will multiple sclerosis affect my career?
# 15     68                List of multiple sclerosis symptoms
# 16     72  Is the Covid-19 vaccine safe for people taking...
# 17     77  How do menopause symptoms relate to multiple s...
# 18     79  Can I pass multiple sclerosis to other family ...
# 19     81  Can I work and study full-time with multiple s...
# 20     83  Why get episode diagnosed by a doctor as a rel...
# 21     85             Relapsing remitting multiple sclerosis
# 22     86           Secondary progressive multiple sclerosis
# 23     92                            causes of fatigue in MS
# 24     93  Does multiple sclerosis relate to sleeping pro...
# 25     94  When will I start to feel better with multiple...
# 26     95                             Reading problems in MS
# 27     96               most efficient and sustainable diets
# 28     97                      benefits of physical activity
# 29     98             most common complications in pregnancy
# 30    101                  heavy flares swelling lymph nodes
# 31    102                             randomly gotten eczema
# 32    105                         wisdom tooth cuts gum pain
# 33    107                            medication adhd anxiety
# 34    108  chronic diarrhea short-term memory sweating in...
# 35    109    ehlers danlos syndrome POTS nausea stomach pain
# 36    112                                 symptoms of asthma
# 37    113                                   asthma and covid
# 38    114           borderline personality disorder symptoms
# 39    116                            outcome prostate cancer
# 40    117             stage 4 metastatic lung cancer outcome
# 41    118    stage 4 triple negative breast cancer treatment
# 42    119                              best pillow neck pain
# 43    121                             numb fingers arthritis
# 44    123                            hypothyroidism symptoms
# 45    126    birth control suppression antral follicle count
# 46    127                               glasses for computer
# 47    130                        neck and shoulder stretches
# 48    131                       exercises for better posture
# 49    132                           headpats scalp psoriasis
# 50    133     psoriasis psoariatic arthritis, lump in armpit
# 51    141                              sores in mouth herpes
# 52    146                              canker sores syphilis
# 53    147                          best supplements creatine
# 54    150                         fish oil supplement dosage
#   Number                                        Description
# 0      1  A 19-year-old male came to clinic with some se...
# 1      2  A 32-year-old woman comes to the hospital with...
# 2      3  A 51-year-old man comes to the office complain...
# 3      4  A 66-year-old woman comes to the office due to...
# 4      5  A 23-year-old man comes to the emergency depar...

# %%
# Step 2: Annotate Description with MedCAT

# We will now proceed to annotate the medical entities present in the description

# Extract the description from the 1st row
chs_text = chs_df.iloc[0]['Description']

# Display the description from the 1st row
print("Description from the 1st row:")
print()
print(chs_text)


# Annotate the description with MedCAT
chs_annotated_text = cat(chs_text)

# Display the annotated medical entities
print()
print("Annotated Medical Entities:")
displacy.render(chs_annotated_text, style='ent')
# Out:
# Description from the 1st row:
#
# What are the most common chronic diseases? What effects do chronic diseases have for the society and the individual?
#
# Annotated Medical Entities:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">What are the most
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     common
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chronic diseases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# ? What
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     effects
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  do
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chronic diseases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  have for the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     society
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
#  and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     individual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">concept</span>
# </mark>
# ?</div></span>

# %%
# Extract medical entities from 'text' using MedCAT and display the results in prettified JSON format.
chs_annotated_text_json = cat.get_entities(chs_text)
chs_prettified_json = json.dumps(chs_annotated_text_json, indent=4)
print(chs_prettified_json)
# Out:
# {
#     "entities": {
#         "0": {
#             "pretty_name": "Common (qualifier value)",
#             "cui": "C0205214",
#             "type_ids": [
#                 "T081"
#             ],
#             "types": [
#                 "Quantitative Concept"
#             ],
#             "source_value": "common",
#             "detected_name": "common",
#             "acc": 0.20545164847206543,
#             "context_similarity": 0.20545164847206543,
#             "start": 18,
#             "end": 24,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 0,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9999736547470093,
#                     "name": "Status"
#                 }
#             }
#         },
#         "2": {
#             "pretty_name": "Chronic disease",
#             "cui": "C0008679",
#             "type_ids": [
#                 "T047"
#             ],
#             "types": [
#                 "Disease or Syndrome"
#             ],
#             "source_value": "chronic diseases",
#             "detected_name": "chronic~disease",
#             "acc": 0.2985924686039612,
#             "context_similarity": 0.2985924686039612,
#             "start": 25,
#             "end": 41,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 2,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9999926090240479,
#                     "name": "Status"
#                 }
#             }
#         },
#         "4": {
#             "pretty_name": "Effect",
#             "cui": "C1280500",
#             "type_ids": [
#                 "T080"
#             ],
#             "types": [
#                 "Qualitative Concept"
#             ],
#             "source_value": "effects",
#             "detected_name": "effect",
#             "acc": 0.30351544155055676,
#             "context_similarity": 0.30351544155055676,
#             "start": 48,
#             "end": 55,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 4,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9999599456787109,
#                     "name": "Status"
#                 }
#             }
#         },
#         "6": {
#             "pretty_name": "Chronic disease",
#             "cui": "C0008679",
#             "type_ids": [
#                 "T047"
#             ],
#             "types": [
#                 "Disease or Syndrome"
#             ],
#             "source_value": "chronic diseases",
#             "detected_name": "chronic~disease",
#             "acc": 0.3199544721321943,
#             "context_similarity": 0.3199544721321943,
#             "start": 59,
#             "end": 75,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 6,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9999909400939941,
#                     "name": "Status"
#                 }
#             }
#         },
#         "8": {
#             "pretty_name": "Persons",
#             "cui": "C0027361",
#             "type_ids": [
#                 "T098"
#             ],
#             "types": [
#                 "Population Group"
#             ],
#             "source_value": "society",
#             "detected_name": "society",
#             "acc": 0.46284506194894504,
#             "context_similarity": 0.46284506194894504,
#             "start": 89,
#             "end": 96,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 8,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.955915093421936,
#                     "name": "Status"
#                 }
#             }
#         },
#         "9": {
#             "pretty_name": "Patients",
#             "cui": "C0030705",
#             "type_ids": [
#                 "T101"
#             ],
#             "types": [
#                 "Patient or Disabled Group"
#             ],
#             "source_value": "individual",
#             "detected_name": "individual",
#             "acc": 0.8451915310883783,
#             "context_similarity": 0.8451915310883783,
#             "start": 105,
#             "end": 115,
#             "icd10": [],
#             "ontologies": [],
#             "snomed": [],
#             "id": 9,
#             "meta_anns": {
#                 "Status": {
#                     "value": "Other",
#                     "confidence": 0.9985184073448181,
#                     "name": "Status"
#                 }
#             }
#         }
#     },
#     "tokens": []
# }

# %% [markdown]
# ### Print CUI and Corresponding Entity Names from Annotated Text.

# %%
# Loop through the annotations in 'chs_annotated_text' and print each CUI and its entity name.

for annotation in list(chs_annotated_text_json['entities'].values()):
    print(annotation['cui'], annotation['pretty_name'])
    print()
# Out:
# C0205214 Common (qualifier value)
#
# C0008679 Chronic disease
#
# C1280500 Effect
#
# C0008679 Chronic disease
#
# C0027361 Persons
#
# C0030705 Patients

# %% [markdown]
# ### Convert CUI to its preferred name
#
# We can convert the CUI to its preferred name by utilizing <code>cdb.cui2preferred_name</code> function in <code>cat</code>.

# %%
# Convert a given CUI back to its preferred name.
cui = "C0205214"
preferred_name = cat.cdb.cui2preferred_name[cui]

# Print the preferred name associated with the CUI.
print(preferred_name)
# Out:
# Common (qualifier value)

# %% [markdown]
# ### Retrieving all names and semantic types for a Given CUI.
#
# We can retrieve all concept names from KB associated with the CUI by utilizing <code>cdb.cdb.cui2names</code> and  <code>cdb.cui2type_ids</code>function in <code>cat</code>.

# %%
# Retrieve all names associated with the CUI from the concept database.
all_names = cat.cdb.cui2names[cui]

# Print the list of names associated with the given CUI.
print(all_names)
# Out:
# {'commonplace', 'conventional', 'prevalent', 'common~values', 'commonly', 'commonest', 'quite~common', 'common', 'common~value', 'less~common'}

# %%
# Retrieve the type_ids associated with the CUI from the concept database.
type_ids = cat.cdb.cui2type_ids[cui]

# Print the list of type_ids associated with the given CUI.
print(type_ids)
# Out:
# {'T081'}
